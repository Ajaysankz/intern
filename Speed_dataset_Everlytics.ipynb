# %% [markdown]
# The Objective
# Perform analysis of a dataset containing vehicle speed information (attached via a link below).
#
# Deliverable is a Python script that works on example dataset. It will generate a report with at least 20 visualizations  (any suitable charts, geo, tables), and text descriptions.
#
# The analysis will include: basic descriptive statistics, outlier detection (e.g. best and worst drivers), and other interesting patterns.
# The emphasis is on speed violation and driver profile analysis
# It is not a requirement, but it'd be nice to include geo visualizations in the report.
#
# It is preferred to use iPython/Jupyter notebook and pandas.
# Visualizations library can be any: matplotlib, plot.ly, Power BI, Tableau etc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# import the packages that is necessary

# %%
data_speed = pd.read_csv("D:\\python\\Speed_dataset.csv")

# %%
data_speed
# Out:
#          latitude  longitude         timestamp  speed_mph  speedlimit_mph  \
# 0       34.640141 -77.938721     6/1/2015 0:04         64              70
# 1       34.643730 -77.939400     6/1/2015 0:04         64              70
# 2       34.551254 -78.784630     6/1/2015 0:04          1              55
# 3       35.613663 -78.470596     6/1/2015 0:06         62              70
# 4       35.614525 -78.474670     6/1/2015 0:06         61              70
# 5       34.860115 -77.999969     6/1/2015 0:19         64              70
# 6       34.328571 -78.926056     6/1/2015 0:24         23              55
# 7       35.756538 -78.699715     6/1/2015 0:30          3              55
# 8       34.402813 -78.916901     6/1/2015 0:33         65              70
# 9       35.039543 -78.149475     6/1/2015 0:34         64              70
# 10      35.042751 -78.150772     6/1/2015 0:34         64              70
# 11      34.443115 -78.959885     6/1/2015 0:36         64              70
# ...

# %% [markdown]
# There are 343628 rows and 11 columns in the data.

# %%
data_speed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343628 entries, 0 to 343627
# Data columns (total 11 columns):
# latitude            343628 non-null float64
# longitude           343628 non-null float64
# timestamp           343628 non-null object
# speed_mph           343628 non-null int64
# speedlimit_mph      343628 non-null int64
# functionalClass     343628 non-null int64
# controlledAccess    343628 non-null object
# isHighway           343628 non-null int64
# state               343628 non-null object
# vehicle_id          343628 non-null int64
# driver_id           343628 non-null int64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 28.8+ MB

# %%
data_speed.isnull().sum()
# Out:
# latitude            0
# longitude           0
# timestamp           0
# speed_mph           0
# speedlimit_mph      0
# functionalClass     0
# controlledAccess    0
# isHighway           0
# state               0
# vehicle_id          0
# driver_id           0
# dtype: int64

# %% [markdown]
# There is no null values in the dataset

# %%
data_speed.describe()
# Out:
#             latitude      longitude      speed_mph  speedlimit_mph  \
# count  343628.000000  343628.000000  343628.000000   343628.000000
# mean       35.504742     -78.495537      38.176129       54.442391
# std         0.794903       0.910243      24.945979       10.014904
# min        33.318760     -84.402771       1.000000       20.000000
# 25%        35.005116     -78.926933      10.000000       45.000000
# 50%        35.531018     -78.458893      44.000000       55.000000
# 75%        35.794942     -78.122360      64.000000       65.000000
# max        38.641785     -75.599670      79.000000       70.000000
#
#        functionalClass      isHighway    vehicle_id     driver_id
# count    343628.000000  343628.000000  3.436280e+05  3.436280e+05
# mean          3.040398       0.683640  8.401167e+05  5.650171e+05
# std           1.368529       0.465056  5.027187e+05  5.193492e+05
# min           0.000000       0.000000  1.429000e+03  0.000000e+00
# ...

# %% [markdown]
# This code describes the descriptive statistics.The mean standard deviation the interquartile range values the lowest value, median and mode is described in this

# %%
data_speed.head()
# Out:
#     latitude  longitude      timestamp  speed_mph  speedlimit_mph  \
# 0  34.640141 -77.938721  6/1/2015 0:04         64              70
# 1  34.643730 -77.939400  6/1/2015 0:04         64              70
# 2  34.551254 -78.784630  6/1/2015 0:04          1              55
# 3  35.613663 -78.470596  6/1/2015 0:06         62              70
# 4  35.614525 -78.474670  6/1/2015 0:06         61              70
#
#    functionalClass controlledAccess  isHighway state  vehicle_id  driver_id
# 0                2                Y          1    NC     1208979       5693
# 1                2                Y          1    NC     1208979       5693
# 2                4                N          1    NC     1262441     916461
# 3                2                Y          1    NC     1280223    1145487
# 4                2                Y          1    NC     1280223    1145487

# %%
data_speed.shape
# Out:
# (343628, 11)

# %%
data_speed.functionalClass.value_counts()
# Out:
# 4    83983
# 2    76635
# 3    62147
# 5    62068
# 1    58783
# 0       12
# Name: functionalClass, dtype: int64

# %% [markdown]
# This code desribes the number of samples included in the each functional class

# %%
data_speed.controlledAccess.value_counts()
# Out:
# N    242914
# Y    100714
# Name: controlledAccess, dtype: int64

# %%
data_speed.isHighway.value_counts()
# Out:
# 1    234918
# 0    108710
# Name: isHighway, dtype: int64

# %%
data_speed['range']=0

# %%
data_speed.head()
# Out:
#     latitude  longitude      timestamp  speed_mph  speedlimit_mph  \
# 0  34.640141 -77.938721  6/1/2015 0:04         64              70
# 1  34.643730 -77.939400  6/1/2015 0:04         64              70
# 2  34.551254 -78.784630  6/1/2015 0:04          1              55
# 3  35.613663 -78.470596  6/1/2015 0:06         62              70
# 4  35.614525 -78.474670  6/1/2015 0:06         61              70
#
#    functionalClass controlledAccess  isHighway state  vehicle_id  driver_id  \
# 0                2                Y          1    NC     1208979       5693
# 1                2                Y          1    NC     1208979       5693
# 2                4                N          1    NC     1262441     916461
# 3                2                Y          1    NC     1280223    1145487
# 4                2                Y          1    NC     1280223    1145487
#
#    range
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
if row ['speed_mph']>row['speedlimit_mph']:
    data_speed ['range'] = 1
else:
    data_speed ['range'] = 0

# %%
data_speed
# Out:
#          latitude  longitude         timestamp  speed_mph  speedlimit_mph  \
# 0       34.640141 -77.938721     6/1/2015 0:04         64              70
# 1       34.643730 -77.939400     6/1/2015 0:04         64              70
# 2       34.551254 -78.784630     6/1/2015 0:04          1              55
# 3       35.613663 -78.470596     6/1/2015 0:06         62              70
# 4       35.614525 -78.474670     6/1/2015 0:06         61              70
# 5       34.860115 -77.999969     6/1/2015 0:19         64              70
# 6       34.328571 -78.926056     6/1/2015 0:24         23              55
# 7       35.756538 -78.699715     6/1/2015 0:30          3              55
# 8       34.402813 -78.916901     6/1/2015 0:33         65              70
# 9       35.039543 -78.149475     6/1/2015 0:34         64              70
# 10      35.042751 -78.150772     6/1/2015 0:34         64              70
# 11      34.443115 -78.959885     6/1/2015 0:36         64              70
# ...

# %% [markdown]
# a new coloumn is imputed with  the data set for proper description

# %% [markdown]
# The dataset consist of 4 continous variable and 7 categorical variable.
# The attributes like latitude , longitude,speed_mph,speedlimit_mph are the continous variable and the rest are categorical variable.

# %% [markdown]
# Vizualisation of the data

# %%
df_num = data_speed[['latitude','longitude','speed_mph','speedlimit_mph']].copy()

f, ax = plt.subplots(figsize=(11, 15))
ax.set(xlim=(-.05, 100))
plt.title("Box Plot of Data Set")
ax = sns.boxplot(data = df_num, orient = 'h', palette = 'Set2')

# %% [markdown]
# By plotting outliers it is identifieable that there are no outlier values for these varables
# for latitude most of the values lies in between 25 to 40.
# for speed mph most of the values lies in between 10 to 65
# majaority values in speedlimit mph lies in between 45 to 65

# %%
corr_matrix = data_speed.corr()
plt.figure(figsize=(13,6))
sns.heatmap(corr_matrix,annot=True,cmap='plasma_r')

# %% [markdown]
# By plotting corelation matrix it can be easily identifiable that which attributes are mostly correlated.By looking at the colour in the figure the functional class and speed_mph are least correlated attributes.Ishighway and the speed is one of the mostly corelated attributes and even the speed and speedlimit have very strong corelation.vehicle id is correlated with latitude and longitude,driver id is corelated with latitude.

# %%
sns.pairplot(data=data_speed, diag_kind = 'kde')

# %% [markdown]
# The pair plots are plotted to check whether the data is normally distributed or not.Looking at the graph it is easily identifiable that the data set is not normally distributed.

# %%
plt.hist(data_speed.driver_id)
plt.xlabel('driver_id')
plt.ylabel('speed_mph')
# Out:
# Text(0,0.5,'speed_mph')

# %%
sns.distplot(data_speed['speed_mph'])
plt.show()
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data_speed['speed_mph'],
             kde=False,
             bins=20)

# Display a plot
plt.show()
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data_speed['speedlimit_mph'],
             kde=False,
             bins=20)

# Display a plot
plt.show()
# Out:
# C:\Users\manoj\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
ct=pd.crosstab(data_speed.isHighway, data_speed.vehicle_id)
ct
# Out:
# vehicle_id  1429     1435     1441     1444     1462     1463     88250    \
# isHighway
# 0                 3        7     3306     2038     2232     1334      657
# 1                 0        0     5101     4321     4822     2926     1200
#
# vehicle_id  88697    90560    118302    ...     1840735  1842323  1843499  \
# isHighway                               ...
# 0              1751     1811     2658   ...         310      532      302
# 1              3854     4227     5322   ...         959     2190      731
#
# vehicle_id  1845975  1846883  1849075  1850001  1851601  1853977  1889852
# isHighway
# 0               544      568      639      104      230      169        2
# 1              1737     1847     1928      318      590      447       19
#
# [2 rows x 63 columns]

# %% [markdown]
# This code represent which all vehicle used the highway.If the vehicle used the highway it is shown as 1 if the vehicle didnt use the highway it is shown as 0

# %%
plt.figure(figsize = (10, 6))
ax = sns.boxplot(x='controlledAccess', y='vehicle_id', data=data_speed)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), <a list of 2 Text xticklabel objects>)

# %% [markdown]
# This figure is a box plot which show the the values. Boxplot are usually used to find outliers
